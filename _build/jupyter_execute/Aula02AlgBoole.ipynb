# %% [markdown]
# ## Álgebra booleana
#
# ## A álgebra booleana é um ramo da matemática que trata de operações lógicas.
#
# ## 1. As variáveis ​​booleanas são representadas como números binários que levam valores lógicos 1 e lógicos 0;
# ## 2. A álgebra booleana também é chamada de lógica de dois valores, Álgebra Binária ou Lógica;
# ## 3. A álgebra booleana foi introduzida pelo matemático George Boole em 1847.
#
# ## A álgebra booleana é fundamental para o desenvolvimento da eletrônica (sistema) digital e é usada em todas as linguagens de programação.

# %% [markdown]
# ## Os níveis lógicos são classificados em dois tipos:
# ## 1. Lógica positiva:\
# ### Lógica 0 = Falso, 0V, Chave Aberta, DESLIGADA\
# ### Lógica 1 = Verdadeiro, +5V, Chave Fechada, LIGADA
# ## 2. Lógica negativa:\
# ### Lógica 0 = Verdadeiro, +5V, Chave Fechada, LIGADA\
# ### Lógica 1 = Falso, 0V, Chave Aberta, DESLIGADA

# %% [markdown]
# # Regras e propriedades da Álgebra Booleana
# ## 1. As variáveis ​​booleanas assumem apenas dois valores, lógico 1 e lógico 0, chamados números binários;
# ## 2. As operações básicas da álgebra booleana são complemento de uma variável, OR e AND de duas ou mais variáveis;
# ## 3. A descrição matemática de operações booleanas usando variáveis ​​é chamada de expressão booleana;
# ## 4. O complemento da variável é representado por uma barra superior (-).\
# ###   Exemplo: 𝑌 = 𝐴̅, Y é a variável de saída
# ## 6. OR de variáveis ​​é representado por um símbolo de mais (+).\
# ###   Exemplo: 𝑌 = 𝐴 + 𝐵, Y é a variável de saída
# ## 8. AND das variáveis ​​é representado por um símbolo de ponto (.).\
# ###   Exemplo:𝑌 = 𝐴. 𝐵, Y é a variável de saída
# ## 10. As operações booleanas são diferentes das operações binárias.\
# ###    Exemplo: 1+1=10 em adição binária e 1+1=1 em álgebra booleana.

# %% [markdown]
# A Tabela 1 abaixo mostra a operação complementar de uma variável, a tabela 2 resumiu a operação OR
# e a tabela 3 resumiu a operação AND de duas variáveis.
#
# Tabela 1
#
# ![image.png](attachment:ffa8b497-af58-4dda-b8ea-948c00717316.png)
#
# Tabela 2
#
# ![image.png](attachment:d3c17b85-3691-40d9-8ec1-014c78b95779.png)
#
# Tabela 3
#
# ![image.png](attachment:863e4b34-bdf2-4de8-81e6-35ebfca93517.png)

# %% [markdown]
# ## Leis Booleanas
#
# ### 1. Comutativa:
# ## A alteração da sequência das variáveis ​​não afeta o resultado ao executar operações OR/AND de expressão booleana.\
# ## ex: A. B = B. A e A + B = B + A
#
# ### 2. Associativa:
# ## A ordem das operações não afeta o resultado final.\
# ## A. (B. C) = (A. B). C e A + (B + C) = (A + B) + C
#
# ### 3. Distributiva:
# ## 𝐴. (𝐵 + 𝐶) = 𝐴. 𝐵 + 𝐴. 𝐶\
# ## 𝐴 + 𝐵𝐶 = (𝐴 + 𝐵)(𝐴 + 𝐶)
#
# ### 4. AND:
# ## 𝐴. 0 = 0\
# ## 𝐴. 1 = 𝐴\
# ## 𝐴. 𝐴 = 𝐴\
# ## 𝐴. 𝐴̅ = 0\
#
# ### 5. OR
# ## 𝐴+0=𝐴\
# ## 𝐴+1=1\
# ## 𝐴+𝐴 = 𝐴\
# ## 𝐴 + 𝐴̅ = 1
#
# ### 6. Inversão/Complemento/Not
# ## $\bar{0} = 1$\
# ## $\bar{1} = 0$
# ## $\bar{\bar{A}} = A$
#
# ### 7. Absorption Law
# ## A(A+B) = A\
# ## A + AB = A\
# ## $A+A\bar{B} = A + B$
#
# ### 8. de Morgan's Laws
# ## 1. def: A soma do complemento de duas ou mais variáveis ​​é igual ao produto do complemento de suas variáveis.\
# ## $\overline{A+B+C+...} = \bar{A}\bar{B}\bar{C}...$
# ## 2. def: O produto do complemento de duas ou mais variáveis ​​é igual à soma dos complemento de suas variáveis.\
# ## $\overline{ABC...} = \bar{A}+\bar{B}+\bar{C}+...$

# %% [markdown]
# ### Justificativa:
#
# Tabela verdade

# %% [markdown]
# ## Tabela de Precedência
#
# ## Operador   | Precedência
# ## -----------|-------------
# ## Parenteses | 1
# ## NOT        | 2
# ## AND        | 3
# ## OR         | 4

# %% [markdown]
# Exercícios:
#
# Simplifique as seguintes expressões
#
# ## 1. $Y = BC+B\bar{C}+BA$
# ## 2. $Y = A+AB+\bar{A}\bar{B}C+\bar{A}\bar{B}\bar{C}D+\bar{A}\bar{B}\bar{C}\bar{D}E$
# ## 3. $Y = C+\bar{BC}$
# ## 4. $Y = \bar{AB}(\bar{A}+B)(\bar{B}+B)$
# ## 5. $Y = (A + C)(AD+A\bar{D})+ AC + C$
# ## 6. $Y = \bar{A}(A+B)+(B+AA)(A+\bar{B})$
# ## 7. $Y = \overline{\overline{A+B\bar{C}}+D(\overline{E+\bar{F}})}$
# ## 8. $Y = AB + A(B+C)+B(B+C)$
# ## 9. $Y = A\bar{B}+A(\overline{B+C})+ B(\overline{B+C})$
# ## 10. $Y = \bar{A}BC + A\bar{B}\bar{C}+\bar{A}\bar{B}\bar{C}+A\bar{B}C+ABC$
# ## 11. Se $F = \bar{A}+B$, $A = Y+X$ e $B = \bar{X}+Y$ determine $F$
# ## 12. Se $f(A,B) = A+B$, mostre que $f(f(X, YX), \bar{X}Y) = X+Y$
# ## 13. Se $A*B = \bar{A}+B$ e $C=A*B$ então $C*A$ é?

# %% [markdown]
# # Realização de expressões booleanas utilizando **portas lógicas**.
#
# ## A porta lógica é o bloco de construção básico de qualquer circuito digital. As portas lógicas podem ter um ou mais entradas e apenas uma saída. A relação entre entrada e saída é baseada em uma certa lógica, que é igual às operações booleanas, como AND, OR e NOT.
#
# ## Com base nas operações booleanas, as portas são nomeadas como porta AND, porta OR e NOT. Essas três portas são chamadas de portas básicas, e mais algumas portas podem ser derivadas usando o método portas básicas, elas são denominadas porta NAND, porta NOR, porta EXOR e porta XNOR.
#
# ## NAND e NOR são chamadas de portas universais, porque usando apenas as portas NAND/ NOR para realizar todas as portas básicas, até mesmo todas as expressões booleanas.

# %% [markdown]
# ![image.png](attachment:b6211e67-4811-4d4d-8fce-83bc64fb9bc1.png)

# %% [markdown]
# ![image.png](attachment:e6cb30ae-226f-48fc-bbc5-43f96faa3a3d.png)

# %% [markdown]
# ![image.png](attachment:2b0ed392-4b44-4a71-a049-3b0ba016dbdc.png)

# %% [markdown]
# ![image.png](attachment:ef33f84a-8587-4dfd-a14b-1a1483560052.png)

# %% [markdown]
# ![image.png](attachment:f5094ef6-7104-4c85-9762-952027f8a170.png)

# %% [markdown]
# ![image.png](attachment:05745a12-ee4e-4a8a-9c54-f081b74337a2.png)

# %% [markdown]
# ![image.png](attachment:5943050b-a48f-4801-9e2f-7d3c11415f9a.png)

# %% [markdown]
# ![image.png](attachment:0914740b-466e-4c8a-b99d-5012100f0dd8.png)

# %% [markdown]
# ![image.png](attachment:0d320325-46a7-44ac-be5d-7859e8f61e6b.png)

# %% [markdown]
# Lista dos circuitos integrados utilizando transistores TTL da série 7400. (https://pt.wikipedia.org/wiki/Lista_dos_circuitos_integrados_da_s%C3%A9rie_7400)
#
#     7400: Quatro portas NAND de duas entradas
#     7401: Quatro portas NAND de duas entradas com coletor aberto
#     7402: Quatro portas NOR de duas entradas
#     7403: Quatro portas NAND de duas entradas com coletor aberto
#     7404: Seis inversores (porta NOT)
#     7405: Seis inversores (porta NOT com saídas com coletor aberto
#     7406: Seis Buffer/Driver inversores com saídas de 30V com coletor aberto
#     7407: Seis Buffer/Driver com saídas de 30V com coletor aberto
#     7408: Quatro portas AND de duas entradas
#     7409: Quatro portas AND de duas entradas com coletor aberto
#     7410: Três portas NAND de três entradas
#     7411: Três portas AND de três entradas
#
#     74876: Oito flip-flops do tipo D
#     74878: Dois flip-flops dp tipo D de 4 bits com clear síncrono e saídas 3-state não-inversoras
#     74879: Dois flip-flops dp tipo D de 4 bits com clear síncrono e saídas 3-state inversoras
#     74880: Oito latches transparentes com saídas inversoras

# %% [markdown]
# ![image.png](attachment:e42153ee-89d9-49e7-a723-088308c2571c.png)

# %% [markdown]
# ![image.png](attachment:9de860d2-b86e-4fb6-bcda-9f8e69df7bdb.png)

# %% [markdown]
# ## Por exemplo:
#
# $Y = AB + BC + AC$
#
# ![image.png](attachment:a41f9564-70ac-48d4-82b5-d34c95643c5d.png)

# %% [markdown]
# ![image.png](attachment:7f243cc4-5895-4b1f-8a8c-c5241e29881a.png)

# %% [markdown]
# ![image.png](attachment:61ca6f4d-7662-4153-9eb6-61384b80943c.png)

# %% [markdown]
# ![image.png](attachment:15145674-0d13-4d94-b964-fe9d80c0e925.png)

# %% [markdown]
# ## Representação de Expressões Booleanas
# ## A relação entre variáveis ​​booleanas e variável de saída é chamada de expressão booleana. As expressões booleanas podem ser representadas de duas formas diferentes, são elas,
# ## 1. Soma de Produtos (SOP) e,
# ## 2. Produto de Somas (POS)

# %% [markdown]
# ### Soma do Produto (SOP)
# As expressões booleanas nas quais o produto das variáveis ​​de entrada são somados para a saída.
# Exemplo: Considere uma tabela verdade mostrada na tabela
#
# ![image.png](attachment:c6db2164-7684-4080-be1a-a7ea71602953.png)
#
# ## onde $Y = \bar{A}\bar{B}C + \bar{A}B\bar{C} + A\bar{B}\bar{C}  + A\bar{B}C + ABC$ é a forma canônica e $Y = A\bar{B}+C\bar{B}+\bar{A}B\bar{C}+AC$ é a sua forma simplificada
#
# OBSERVAÇÃO:
# 1. A forma SOP canônica para a forma SOP mínima e vice-versa também pode ser derivada usando a tabela verdade.
# 2. Cada termo de produto do formulário SOP é chamado de mintermos.
# 3. A forma canônica SOP de expressões booleanas também pode ser escrita usando o equivalente decimal de
# variáveis ​​de entrada para a saída alta.
# Exemplo: para a expressão booleana (1), a saída é alta para ABC=001, ABC=010 ABC=100,ABC=101 e ABC=111.
# O equivalente decimal de ABC=001 é '1', ABC=010 é '2', ABC=100 é '4', ABC=101 é '5' e ABC = 111 é '7'
# Portanto, Y também pode ser expresso como
#
# ![image.png](attachment:5ca1e57d-0c88-471d-89c2-e6d2157e6d47.png)

# %% [markdown]
# ### Exercício
#
# ![image.png](attachment:bac479e0-fd4a-4868-9837-f52ef2a8a9a9.png)
#
# Resposta: $Y = A\bar{B}+C\bar{B}+\bar{A}B\bar{C}+AC$
#
# ![image.png](attachment:5a0d89bf-cec5-4420-ae70-c2a1a17dd5be.png)

# %% [markdown]
# ## Produto da Soma (POS)
# As expressões booleanas nas quais a soma das variáveis ​​de entrada são multiplicadas para saída
#
# Exemplo: Considere uma tabela verdade mostrada na tabela
#
# ![image.png](attachment:8bf8bc8d-6cf0-453c-bc1f-21f655397af7.png)
#
# $Y = (A+B+C)(A+\bar{B}+\bar{C})(\bar{A}+\bar{B}+C)$
#
# $Y = (A + C)(\bar{A}+\bar{B})$
#
# OBSERVAÇÃO:
# 1. O formato POS canônico para o formato POS mínimo e vice-versa também pode ser derivado usando a tabela verdade.
# 2. Cada termo de soma do formulário POS é chamado de maxterm.
# 3. A forma canônica POS de expressões booleanas também pode ser escrita usando o equivalente decimal de
# variáveis ​​de entrada para a saída alta.
# Exemplo: para a expressão booleana (1), a saída é baixa para ABC=000, ABC=011 e ABC=110.
# O equivalente decimal de ABC=000 é '0', ABC=011 é '3' e ABC=110 é '6'
# Portanto, Y também pode ser expresso como
#
# ![image.png](attachment:fbe01098-2de8-434e-9c38-675bf35e7de1.png)
