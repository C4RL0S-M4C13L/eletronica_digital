# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Informações da Disciplina
#
# ## ED311 - Eletrônica Digital
#
# ### Dept Engenharia Elétrica
#
# ### Faculdade de Engenharia e Ciências de Guaratinguetá
#
# ### Universidade Estadual Paulista
#
#
#
# ### Versão 2024
#
# ### Essas notas de aula podem ser compartilhadas nos termos da licença Creative Commons CC BY-NC-ND 4.0, com propósitos exclusivamente educacionais.
#
# ### Attribution-NonCommercial-NoDerivatives 4.0 International
#
#
# <img src="imagens/CC.png"/>

# %% [markdown]
# # Objetivo:
# ## Fornecer aos alunos os conceitos de lógica digital usando circuitos lógicos combinatoriais, sequencias e HDL
#
# ## ementa:
#     1. sistemas de numeração e aritmética básica
#     2. formas canônicas da álgebra de Boole
#     3. Circuitos sequências
#     4. Diagramas de fluxos e tabelas de estados
#
# ## Método de aula
# ### aulas expositivas, exercícios em sala de aula e projeto.
#
# ## Bibliografia
#
# ### 1. notas de aula
# ### 2. Livro1
#
# ## Datas das avaliações
#     P1 - 23 de abril de 2024
#     P2 - 18 de junho de 2024
#     As aulas antes das avaliações são para tirar dúvidas

# %% [markdown]
# # Introdução/Justificativa
#
# ## 1. As implementações digitais são mais flexíveis do que as analógicas
# ## 2. Permite a implementação de algoritmos mais complexos p.ex. correção de erro
# ## 3. Facilita a integração e escala de circuitos integrados de forma mais simples

# %% [markdown]
# # Exemplos

# %% [markdown]
# ## 1. Próteses
# ---

# %%
YouTubeVideo('GgTwa3CPrIE', width=800, height=600)

# %% [markdown]
# ## 2. Carros autônomos
# ---

# %%
YouTubeVideo('cMlGyIJH5L8', width=800, height=600)

# %% [markdown]
# # Relação entre as disciplinas da Graduação
#
# <img src="imagens/RelacaoDisciplinas.png" width="640" height="140" align="center"/>

# %% [markdown]
# # OBJETIVOS
# 1. Analisar e projetar redes de chaveamento, combinacionais e sequenciais, implementadas com circuitos integrados padrões e componentes programáveis após o encapsulamento - CPLD/FPGA.
# 2. Propiciar ao aluno verificar na prática os conceitos vistos na teoria. Ao final da disciplina o aluno será capaz de conhecer os principais componentes da lógica digital, utilizando-os no desenvolvimento de projetos.

# %% [markdown]
# # Bibliografia
#
#     - Simon Haykin & Barry Van Veen, Sinais e Sistemas, Bookman, 2001 - Porto Alegre.
#     - Alan V. Oppenheim, Alan S. Willky with Ian T. Young, Signals and Systems, Prentice-Hall, 1983.
#     - notas de aula

# %% [markdown]
# # Planejamento do Curso 2024
#
# |Conteúdo|Data||Conteúdo|Data|
# |:---:|:---:|:---:|:---:|:---:|
# |Apresentação; sinais e sistemas        | 16/08 | |Transformada de Fourier   | 17/10 |
# |Energia e Potência, sinais complexos   | 22/08 | |1a. Prova                 | 24/10 |
# |Sistemas; classificação de sistemas    | 29/08 | |Série de Fourier          | 31/10 |
# |Sistemas LIT; Convolução               | 12/09 | |TF de funções especiais   | 07/11 |
# |Propriedades de sistemas LIT           | 19/09 | |Diagrama de Bode          | 21/11 |
# |Propriedades e Aplicações em EDO       | 26/09 | |Introdução a Filtros 1/2  | 28/11 |
# |Transformada de Laplace                | 03/10 | |Introdução a Filtros 2/2  | 05/12 |
# |Propriedades da TL e sua inversa       | 10/10 | |2a. Prova                 | 06/12 |

# %% [markdown]
# # What is Electronic Design Automation (EDA)?
#
# ## The Intel 4004, the world’s first commercially available microprocessor, was built from approximately 2300 transistors, and had a clock frequency of 740 kilohertz (thousands of cycles per second) [1] [2]. A modern Intel microprocessor can contain over 1.5 billion transistors, and will typically have a clock frequency ranging from two to four gigahertz (billions of cycles per second).
#
# ## In 1971 it took less than one hundred people to manufacture the 4004. That is approximately 23 transistors per employee. If that ratio stayed the same between 1971 and 2012, Intel would need to employ about 65 million people just to produce the latest Core i7 processor. That is one fifth the entire population of the United States!
#
# [1]	Wikipedia: Intel 4004\
# [2]	The Story of the Intel 4004

# %% [markdown]
# ![image.png](attachment:409740bb-7c5e-4ad7-9451-c36868126ec0.png)
# https://www.techtudo.com.br/noticias/2011/11/intel-4004-o-primeiro-processador-da-historia-comemora-40-anos-de-idade.ghtml

# %% [markdown]
# ![image.png](attachment:322cc767-6780-4dc4-9d76-d67e534f3d67.png)
#
# http://www.intel4004.com/

# %% [markdown]
# ## Cuidados com as aula
#
# https://www.instagram.com/p/CpBc29LtJPM/?igshid=MDJmNzVkMjY=

# %% [markdown]
# ![image.png](attachment:da5e45d7-9dcb-4f26-a9a4-d23e53e80c6f.png)

# %% [markdown]
# ![image.png](attachment:aaebf58f-96d2-4cf0-9457-38db4e14f649.png)

# %% [markdown]
# ![image.png](attachment:42bcd78d-4a33-4ed1-b53b-16ce889eb05c.png)

# %% [markdown]
# ![image.png](attachment:a007b81b-10c9-45af-ab56-0b0ed3708c63.png)

# %% [markdown]
# ![image.png](attachment:c601a7dd-db25-432b-bb67-9204b0a1f4ee.png)

# %% [markdown]
# ![image.png](attachment:4c229376-2737-43ca-947e-cfdcbb4faba6.png)
