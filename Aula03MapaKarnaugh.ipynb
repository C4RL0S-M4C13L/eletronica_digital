# %% [markdown]
# # Mapa de Karnaugh

# %% [markdown]
# ## A simplificação de expressões usando regras algébricas booleanas não é única e, geralmente, a expressão resultante não está na forma mínima.
#
# ## Para obter a orma mínima final, será utilizada a técnica **Mapa de Karnaugh**(K-maps). A introdução para K-maps, agrupamento de variáveis ​​e procedimentos de simplificação são discutidos com exemplos.
#
# ## OBSERVAÇÃO:\
# ### 1. Número de células no K-map = número de casos possíveis
# ### 2. Nº de casos possíveis=$2^𝑁$
# ### 3. N é o número de variáveis ​​de entrada.

# %% [markdown]
# ## Procedimento:
# ### 1. Selecione o número de células conforme o número de variáveis ​​de entrada.
# ### 2. Identifique se o problema em questão é o formato SOP ou POS, mintermos para a forma SOP e maxtermos para forma POS.
# ### NOTA: No formulário SOP, preencha as células com 1 nos mintermos correspondentes e caso contrário preencha com 0's.\
# ### NOTA: No formulário POS, preencha as células com 0 nos maxtermos correspondentes e caso contrário preencha com 1's.\
# ### NOTA: No formato POS, pegue o complemento da variável de saída para obter o
#
# ## expressão resultante.
# ### 3. agrupe os termos na forma retangular, o número total de termos é 2, 4, 8, etc., tente cubra tantos elementos quanto possível em um grupo.
# ### 4. nos grupos, encontre os termos do produto para SOP e os termos de soma para o formulário POS.

# %% [markdown]
# ![image.png](attachment:8bae4043-eceb-462f-a91f-e6ba52519716.png)
#
# $Y = \bar{A}\bar{D}+\bar{A}\bar{B}C+AD$

# %% [markdown]
# ---
#
#   $Y = BC+B\bar{C}+BA$
#
#   $Y = BC(A+\bar{A})+(A+\bar{A})B\bar{C}+BA(C+\bar{C})$
#
#   $Y = ABC + \bar{A}BC + AB\bar{C}+\bar{A}B\bar{C} + ABC + AB\bar{C}$
#
#   $Y = ABC + \bar{A}BC + AB\bar{C}+\bar{A}B\bar{C}$
#
#   $Y = \sum m(2, 3, 6, 7)$
#
#
#
#   | C\AB | 00 | 01 | 11 | 10 |
#   |------|----|----|----|----|
#   | 0    |  0 |  1 |  1 | 0  |
#   | 1    |  0 | 1  |  1 |  0 |
#
#
#
#   $ Y = B$

# %% [markdown]
# ---
# A noção de **don't care**
#
# O mapa de Karnaugh é preenchido com **x** e pode assumir **0** ou **1**.
#
# ---

# %% [markdown]
# ---
# ## Exercícios
#
# ## 1. F(A, B, C, D) = Σm(0, 1, 2, 5, 7, 8, 9, 10, 13, 15)
# ## 2. F(A, B, C, D) = Σm(1, 3, 4, 6, 8, 9, 11, 13, 15) + Σd(0, 2, 14)
# ## 3. F(A, B, C) = Σm(0, 1, 6, 7) + Σd(3, 5)
# ## 4. F(A, B, C) = Σm(1, 2, 5, 7) + Σd(0, 4, 6)
# ## 5. F(A, B, C) = Σm(0, 1, 6, 7) + Σd(3, 4, 5)
# ## 6. F(A, B, C, D) = Σm(0, 2, 8, 10, 14) + Σd(5, 15)
# ## 7. F(A, B, C, D) = Σm(3, 4, 5, 7, 9, 13, 14, 15)
# ## 8. F(W, X, Y, Z) = Σm(1, 3, 4, 6, 9, 11, 12, 14)

# %% [markdown]
# https://www.boolean-algebra.com/

# %% [markdown]
# ![image.png](attachment:7588b1ac-4280-4b0d-b963-9dda85fcad13.png)

# %% [markdown]
# ![image.png](attachment:4d2a85e8-e41c-46a1-9c4e-3ffbc5b923a7.png)

# %% [markdown]
# ![image.png](attachment:07d277a3-9f00-47e0-bd05-cd315d0c28d9.png)

# %% [markdown]
# ![image.png](attachment:9ba209eb-8b0b-4f61-9d7d-b37cd47d2a87.png)
